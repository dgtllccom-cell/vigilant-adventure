# %%
import subprocess
import os

cwd = r"c:\Users\dgtll\OneDrive\Documents\ACCOUNTS.DGT.LLC"
result = subprocess.run(
    ["git", "checkout", "--", "features/roznamcha/components/super-admin-roznamcha-report-view.tsx"],
    cwd=cwd,
    capture_output=True,
    text=True
)
print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
print("RETURN CODE:", result.returncode)
